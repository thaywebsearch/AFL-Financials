# %%
#Convert the adjusted closing prices to cymulative returns.
returns = afl.pct_change()
((1 + returns).cumprod() -1).plot(title='AFL Cumulative Returns')

# %%
from pandas_datareader import data
#Get the adjust close.
afl = data.DataReader("AFL", start='2020-01-01', end='2020-12-31', data_source='yahoo')['Adj Close']

afl.plot(title='AFL Adj. Closing Price')
# Out:
# <AxesSubplot:title={'center':'AFL Adj. Closing Price'}, xlabel='Date'>
