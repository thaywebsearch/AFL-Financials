# %%
import yfinance as yf

mfc = yf.Ticker('mfc')

hist = mfc.history(period="max")

print(mfc.history)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python310\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\AppData\Roaming\Python\Python310\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72
# ---> 73     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      74         af, socktype, proto, canonname, sa = res
#
# c:\Program Files\Python310\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     954     addrlist = []
# --> 955     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     956         af, socktype, proto, canonname, sa = res
#
# ...

# %%
import yfinance as yf

mfc = yf.Ticker('mfc')

print(mfc.balance_sheet)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python310\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\AppData\Roaming\Python\Python310\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72
# ---> 73     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      74         af, socktype, proto, canonname, sa = res
#
# c:\Program Files\Python310\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     954     addrlist = []
# --> 955     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     956         af, socktype, proto, canonname, sa = res
#
# ...
