# %%
import yfinance as yf
import pandas as pd

yf.download('BAC', period='10y')

bac = yf.download('BAC', period='10y')

bac.head()

bac['Adj Close'].plot(figsize=[10,5], legend=True),
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# (<AxesSubplot:xlabel='Date'>,)
