# %%
import yfinance as yahooFinance


GetSanofiInformation = yahooFinance.Ticker("SNY")

# display Company Sector
print("Company Sector : ", GetSanofiInformation.info['sector'])

# display Price Earnings Ratio
print("Price Earnings Ratio : ", GetSanofiInformation.info['trailingPE'])

# display Company Beta
print(" Company Beta : ", GetSanofiInformation.info['beta'])
# Out:
# Company Sector :  Healthcare
# Price Earnings Ratio :  17.154194
#  Company Beta :  0.458218

# %%
import yfinance as yahooFinance
GetSanofiInformation = yahooFinance.Ticker("SNY")

# get all key value pairs that are available
for key, value in GetSanofiInformation.info.items():
	print(key, ":", value)
# Out:
# zip : 75008
# sector : Healthcare
# fullTimeEmployees : 99412
# ...

# %%
import yfinance as yahooFinance


GetSanofiInformation = yahooFinance.Ticker("SNY")

# Let us get historical stock prices for Sanofi
# covering the past few years.
# max->maximum number of daily prices available
# for Sanofi.
# Valid options are 1d, 5d, 1mo, 3mo, 6mo, 1y, 2y,
# 5y, 10y and ytd.
print(GetSanofiInformation.history(period="max"))
# Out:
#                  Open       High        Low      Close   Volume  Dividends  \
# Date
# 2002-07-01  15.498549  15.518876  15.092030  15.127601   196800        0.0
# 2002-07-02  14.990399  15.000562  14.533065  14.660102    54500        0.0
# 2002-07-03  14.736324  14.883688  14.380620  14.533065    61900        0.0
# 2002-07-05  15.320696  15.447733  15.320696  15.447733    11700        0.0
# 2002-07-08  15.849174  16.032107  15.727218  15.879663    77400        0.0
# ...               ...        ...        ...        ...      ...        ...
# 2021-11-30  48.099998  48.250000  47.259998  47.570000  1659000        0.0
# 2021-12-01  48.009998  48.709999  47.720001  48.060001  2242500        0.0
# 2021-12-02  47.950001  48.029999  47.490002  47.689999  1693100        0.0
# 2021-12-03  47.439999  47.529999  46.930000  47.070000  2043200        0.0
# 2021-12-06  47.529999  47.799999  47.419998  47.560001  1237900        0.0
#
#             Stock Splits
# Date
# 2002-07-01             0
# ...

# %%
import yfinance as yahooFinance


GetSanofiInformation = yahooFinance.Ticker("SNY")

# Valid options are 1d, 5d, 1mo, 3mo, 6mo, 1y,
# 2y, 5y, 10y and ytd.
print(GetSanofiInformation.history(period="6mo"))
# Out:
#                  Open       High        Low      Close   Volume  Dividends  \
# Date
# 2021-06-07  52.259998  52.700001  52.160000  52.230000  3434700          0
# 2021-06-08  52.580002  52.580002  51.900002  52.060001   929800          0
# 2021-06-09  52.520000  52.910000  52.470001  52.779999  2659800          0
# 2021-06-10  53.419998  53.990002  53.360001  53.779999  1543400          0
# 2021-06-11  53.849998  53.910000  53.509998  53.799999   872700          0
# ...               ...        ...        ...        ...      ...        ...
# 2021-11-30  48.099998  48.250000  47.259998  47.570000  1659000          0
# 2021-12-01  48.009998  48.709999  47.720001  48.060001  2242500          0
# 2021-12-02  47.950001  48.029999  47.490002  47.689999  1693100          0
# 2021-12-03  47.439999  47.529999  46.930000  47.070000  2043200          0
# 2021-12-06  47.529999  47.799999  47.419998  47.560001  1237900          0
#
#             Stock Splits
# Date
# 2021-06-07             0
# ...

# %%
import yfinance as yahooFinance

# in order to specify start date and
# end date we need datetime package
import datetime

# startDate , as per our convenience we can modify
startDate = datetime.datetime(2019, 5, 31)

# endDate , as per our convenience we can modify
endDate = datetime.datetime(2021, 1, 30)
GetSanofiInformation = yahooFinance.Ticker("SNY")

# pass the parameters as the taken dates for start and end
print(GetSanofiInformation.history(start=startDate,
									end=endDate))
# Out:
#                  Open       High        Low      Close   Volume  Dividends  \
# Date
# 2019-05-30  37.843533  38.010777  37.685582  37.927155   844500        0.0
# 2019-05-31  37.574079  37.601955  37.341796  37.564789   607100        0.0
# 2019-06-03  38.243055  38.410299  38.075811  38.187305   842500        0.0
# 2019-06-04  38.596127  38.689039  38.382427  38.503212   585200        0.0
# 2019-06-05  38.521796  38.661167  38.326679  38.577545   896300        0.0
# ...               ...        ...        ...        ...      ...        ...
# 2021-01-25  47.534642  47.842995  47.390100  47.823723  2058300        0.0
# 2021-01-26  47.785176  47.814083  47.187742  47.361191  2598000        0.0
# 2021-01-27  47.004658  47.004658  45.607433  45.607433  2349500        0.0
# 2021-01-28  45.963965  46.310864  45.780878  45.838696  3332800        0.0
# 2021-01-29  45.790513  45.877238  44.865453  45.491795  4015100        0.0
#
#             Stock Splits
# Date
# 2019-05-30             0
# ...
