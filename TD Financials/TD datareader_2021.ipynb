# %%
from pandas_datareader import data

td = data.DataReader("TD", start='2021-01-01', end='2021-12-31', data_source='yahoo')['Adj Close']

td.plot(title='TD Adj. Closing Price')
# Out:
# <AxesSubplot:title={'center':'TD Adj. Closing Price'}, xlabel='Date'>
