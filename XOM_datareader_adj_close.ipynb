# %%
from pandas_datareader import data

xom = data.DataReader("XOM", start='2020-01-01', end='2020-12-31', data_source='yahoo')['Adj Close']

xom.plot(title='XOM Adj. Closing Price')
# Out:
# <AxesSubplot:title={'center':'XOM Adj. Closing Price'}, xlabel='Date'>
